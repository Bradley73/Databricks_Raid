# %%
# %sh
pwd
ls

# %%
# %sh

cd /Workspace/Users/bradstan@live.co.uk/Databricks_Raid/projects/raid

python -m pip install -U pip
python -m pip install dbt-core dbt-databricks

dbt --version
dbt init dbt
