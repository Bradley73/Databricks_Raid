# %%
# %pip install --quiet "dbt-databricks"
dbutils.library.restartPython()

# %%
# !dbt --version

# %%
import os
DBT_PROJECT_DIR = "/Workspace/Users/bradstan@live.co.uk/Databricks_Raid/projects/raid/transform"
os.chdir(DBT_PROJECT_DIR)
print("CWD:", os.getcwd())

# %%
os.environ["DBT_PROFILES_DIR"] = DBT_PROJECT_DIR
os.environ["DATABRICKS_HOST"] = "https://dbc-24b992ba-2256.cloud.databricks.com"
os.environ["DATABRICKS_HTTP_PATH"] = "/sql/1.0/warehouses/af5a9c053ad1252e"
os.environ["DATABRICKS_TOKEN"] = ""

# optional overrides
os.environ["DATABRICKS_CATALOG"] = "workspace"
os.environ["DBT_SCHEMA"] = "raid"

# %%
# !dbt debug --target dev

# %%
# !dbt deps

# !dbt build -s +champindex_current --target dev
# !dbt snapshot --target dev
# !dbt build --target dev

# %%
# !dbt parse
