-- %%
CREATE SCHEMA IF NOT EXISTS raid;

CREATE TABLE IF NOT EXISTS raid.bronze_champindex (
  AccountName STRING,
  ID INT,
  HeroID INT,
  Name STRING,
  Rank INT,
  Level INT,
  EmpowerLevel INT,
  Rarity INT,
  Affinity INT,
  Faction INT,
  UsedT1MasScrolls INT,
  UnUsedT1MasScrolls INT,
  UsedT2MasScrolls INT,
  UnUsedT2MasScrolls INT,
  UsedT3MasScrolls INT,
  UnUsedT3MasScrolls INT,
  HP INT,
  ATK INT,
  DEF INT,
  CritRate INT,
  CritDamage INT,
  SPD INT,
  ACC INT,
  RES INT,
  BlessingID INT,
  BlessingGrade INT,

  _rescued_data STRING,

  run_id STRING,
  source_file STRING,
  snapshot_ts TIMESTAMP,
  snapshot_version INT,
  snapshot_date DATE,
  schema_version STRING
)
USING DELTA
PARTITIONED BY (AccountName, snapshot_date);
